# %% [markdown]
# # Video Game Sales Data Analysis from 1980 -2020

# %%
import pandas as pd
data=pd.read_csv(r"E:\python package\vgsales.csv")

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
data.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
data.tail()
# Out:
#         Rank                                              Name Platform  \
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year     Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 16593  2002.0  Platform       Kemco      0.01      0.00       0.0
# 16594  2003.0   Shooter  Infogrames      0.01      0.00       0.0
# 16595  2008.0    Racing  Activision      0.00      0.00       0.0
# 16596  2010.0    Puzzle    7G//AMES      0.00      0.01       0.0
# 16597  2003.0  Platform     Wanadoo      0.01      0.00       0.0
#
#        Other_Sales  Global_Sales
# 16593          0.0          0.01
# 16594          0.0          0.01
# ...

# %%
data.shape  ##no of rows and columns in the data set
# Out:
# (16598, 11)

# %%
data.size  ##no of elements in the data set
# Out:
# 182578

# %%
data.columns
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %% [markdown]
# # Checking for duplicate

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Rank, Name, Platform, Year, Genre, Publisher, NA_Sales, EU_Sales, JP_Sales, Other_Sales, Global_Sales]
# Index: []

# %% [markdown]
# # Heat map for null values in data set

# %%
data.isnull().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # For which platform more games were produced?

# %%
data.head(2)
# Out:
#    Rank               Name Platform    Year     Genre Publisher  NA_Sales  \
# 0     1         Wii Sports      Wii  2006.0    Sports  Nintendo     41.49
# 1     2  Super Mario Bros.      NES  1985.0  Platform  Nintendo     29.08
#
#    EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     29.02      3.77         8.46         82.74
# 1      3.58      6.81         0.77         40.24

# %%
data['Platform'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Show sales analysis for wii sports game in a bar graph

# %%
data1 = data[["Name","Platform","NA_Sales","EU_Sales","JP_Sales","Other_Sales","Global_Sales"]]

# %%
data1[(data1['Name']=='Wii Sports')].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Which genre of games were produced the most?

# %%
data.head(5)
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
data['Genre'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
def autopct(pct):
    return ('%.2f' % pct) if pct > 0 else ''

# %%
data['Genre'].value_counts().plot(kind='pie',autopct=autopct,figsize=(20,10))
# Out:
# <AxesSubplot:ylabel='Genre'>

# %% [markdown]
# # In Which year highest no.of wii platform games have been released?

# %%
data_wii=data[data['Platform']=='Wii']

# %%
data_wii.Year.value_counts()
# Out:
# 2009.0    325
# 2008.0    282
# 2010.0    254
# 2007.0    187
# 2011.0    144
# 2006.0     44
# 2012.0     32
# 2013.0     12
# 2014.0      6
# 2015.0      4
# Name: Year, dtype: int64

# %%
data_wii.Year.value_counts().plot(kind='line')
# Out:
# <AxesSubplot:>

# %%
data_wii.Year.value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Year'>

# %%
data_wii.Year.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Which game is the oldest?

# %%
data.sort_values(by='Year').head(1)
# Out:
#       Rank      Name Platform    Year Genre Publisher  NA_Sales  EU_Sales  \
# 6896  6898  Checkers     2600  1980.0  Misc     Atari      0.22      0.01
#
#       JP_Sales  Other_Sales  Global_Sales
# 6896       0.0          0.0          0.24

# %% [markdown]
# # In which year highest no.of games were produced?

# %%
data.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
data['Year'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Which game has the highest no.of North America Sales?

# %%
data.sort_values(by='NA_Sales').tail(1)
# Out:
#    Rank        Name Platform    Year   Genre Publisher  NA_Sales  EU_Sales  \
# 0     1  Wii Sports      Wii  2006.0  Sports  Nintendo     41.49     29.02
#
#    JP_Sales  Other_Sales  Global_Sales
# 0      3.77         8.46         82.74

# %% [markdown]
# # Which game has the lowest no.of Europe Sales?

# %%
data.sort_values(by='EU_Sales').head(1)
# Out:
#         Rank              Name Platform    Year     Genre Publisher  NA_Sales  \
# 16597  16600  Spirits & Spells      GBA  2003.0  Platform   Wanadoo      0.01
#
#        EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 16597       0.0       0.0          0.0          0.01

# %% [markdown]
#  # Show the pairplot analysis of data

# %%
sns.pairplot(data)

# %% [markdown]
# # Show the relation between sales in North America and Europe using scatterplot

# %%
sns.relplot(x='NA_Sales',y='EU_Sales',data=data)

# %% [markdown]
# # Show the relation of japan sales with global sales

# %%
sns.relplot(x='JP_Sales',y='Global_Sales',kind='line',data=data)

# %% [markdown]
# # Show the relation of Europe sales with global sales with catplot

# %%
sns.catplot(x='EU_Sales',y='Global_Sales',data=data)

# %%
data.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %% [markdown]
# # Top 10 Selling games overall

# %%
data.head(10)
# Out:
#    Rank                       Name Platform    Year         Genre Publisher  \
# 0     1                 Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2          Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3             Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4          Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5   Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
# 5     6                     Tetris       GB  1989.0        Puzzle  Nintendo
# 6     7      New Super Mario Bros.       DS  2006.0      Platform  Nintendo
# 7     8                   Wii Play      Wii  2006.0          Misc  Nintendo
# 8     9  New Super Mario Bros. Wii      Wii  2009.0      Platform  Nintendo
# 9    10                  Duck Hunt      NES  1984.0       Shooter  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# ...

# %% [markdown]
# # Which publisher has published highest no.of video games?

# %%
sns.set(rc = {'figure.figsize':(15,8)})

# %%
data['Publisher'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Publisher'>

# %% [markdown]
# # Answer:Electronic Arts

# %% [markdown]
# # Top 20 Games published by Activision

# %%
data_act=data[data['Publisher']=='Activision']

# %%
data_act.head(20)
# Out:
#      Rank                            Name Platform    Year         Genre  \
# 29     30  Call of Duty: Modern Warfare 3     X360  2011.0       Shooter
# 31     32         Call of Duty: Black Ops     X360  2010.0       Shooter
# 33     34       Call of Duty: Black Ops 3      PS4  2015.0       Shooter
# 34     35      Call of Duty: Black Ops II      PS3  2012.0       Shooter
# 35     36      Call of Duty: Black Ops II     X360  2012.0       Shooter
# 36     37  Call of Duty: Modern Warfare 2     X360  2009.0       Shooter
# 37     38  Call of Duty: Modern Warfare 3      PS3  2011.0       Shooter
# 40     41         Call of Duty: Black Ops      PS3  2010.0       Shooter
# 55     56  Call of Duty: Modern Warfare 2      PS3  2009.0       Shooter
# 61     62            Call of Duty: Ghosts     X360  2013.0       Shooter
# 67     68            Call of Duty: Ghosts      PS3  2013.0       Shooter
# 70     71  Call of Duty 4: Modern Warfare     X360  2007.0       Shooter
# ...

# %% [markdown]
# # Top 15 Games published by Electronic arts for PS4

# %%
data_EA=data[(data['Publisher']=='Electronic Arts') & (data['Platform']=='PS4')]

# %%
data[(data['Publisher']=='Electronic Arts') & (data['Platform']=='PS4')].head(15)
# Out:
#       Rank                          Name Platform    Year         Genre  \
# 77      78                       FIFA 16      PS4  2015.0        Sports
# 92      93  Star Wars Battlefront (2015)      PS4  2015.0       Shooter
# 124    125                       FIFA 15      PS4  2014.0        Sports
# 221    222                       FIFA 17      PS4  2016.0        Sports
# 386    387                 Battlefield 4      PS4  2013.0       Shooter
# 418    419                 Madden NFL 16      PS4  2015.0        Sports
# 493    494                       FIFA 14      PS4  2013.0        Sports
# 650    651         Need for Speed (2015)      PS4  2015.0        Racing
# 797    799         Battlefield: Hardline      PS4  2015.0       Shooter
# 836    838                 Madden NFL 15      PS4  2014.0        Sports
# 858    860       Dragon Age: Inquisition      PS4  2014.0  Role-Playing
# 909    911         Need for Speed Rivals      PS4  2013.0        Racing
# ...

# %%
data_EA['Name'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Name'>

# %% [markdown]
# # How many Racing games were published?

# %%
data.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
data[(data['Genre']=='Racing')].head()
# Out:
#     Rank                    Name Platform    Year   Genre  \
# 2      3          Mario Kart Wii      Wii  2008.0  Racing
# 11    12           Mario Kart DS       DS  2005.0  Racing
# 28    29  Gran Turismo 3: A-Spec      PS2  2001.0  Racing
# 42    43            Mario Kart 7      3DS  2011.0  Racing
# 47    48          Gran Turismo 4      PS2  2004.0  Racing
#
#                       Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 2                      Nintendo     15.85     12.88      3.79         3.31
# 11                     Nintendo      9.81      7.57      4.13         1.92
# 28  Sony Computer Entertainment      6.85      5.09      1.87         1.16
# 42                     Nintendo      4.74      3.91      2.67         0.89
# 47  Sony Computer Entertainment      3.01      0.01      1.10         7.53
#
#     Global_Sales
# 2          35.82
# 11         23.42
# 28         14.98
# 42         12.21
# 47         11.66

# %%
data[(data['Genre']=='Racing')].shape
# Out:
# (1249, 11)

# %% [markdown]
# # Answer is: 1249
